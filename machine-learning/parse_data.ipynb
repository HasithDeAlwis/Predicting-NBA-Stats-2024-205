# %%
import os
import pandas as pd
from bs4 import BeautifulSoup
from io import StringIO

# %%
#get the full file path to our player's stats
PLAYER_STATS_2_DIR = "data/player_stats_2"
player_stats = os.listdir(PLAYER_STATS_2_DIR)
#only take the files that have .html
player_stats = [os.path.join(PLAYER_STATS_2_DIR, player) for player in player_stats if player.endswith(".html")]
print(player_stats[2])
len(player_stats)
# Out:
# data/player_stats_2/oubreke01.html
# 574

# %%
def read_file(player):
    with open(player) as f:
        html = f.read()
    soup = BeautifulSoup(html, 'html.parser')
    return soup

# %%
def make_df(stats):
    stats = str(stats)
    df_stats = pd.read_html(StringIO(stats))[0]
    return df_stats

# %%
def decompose_table(table):
    if (table is not None):
        table.find('colgroup').decompose()
        table.find('thead').decompose()
        table.find('caption').decompose()
        table.find('tfoot').decompose()
        
        body = table.find('tbody')
        table_rows = body.find_all('tr')
        
        for row in table.find_all('tr'):
            if row not in table_rows:
                row.decompose()
        return table
    return None

# %%
def determine_teams_and_year(player_soup):
    teamArray = []
    
    table = player_soup.find(id="per_minute")
    table_body = table.find('tbody')
    multipleTeamFlag = False
    
    year = "NaN"
    for row in table_body.find_all('tr'):
        team = row.find(attrs={'data-stat': 'team_id'})

        if team:
            if team.text == "TOT":
                multipleTeamFlag = True
                year = row.find(attrs={'data-stat': 'season'}).text
                year = year.split("-")[0][:2] + year.split("-")[1]
                continue
            team_link = team.find("a")['href']
            split_team_id = team_link.split("/")
            file = split_team_id[2] + split_team_id[3]
            if year in split_team_id[3]:
                if len(teamArray) >= 1:
                    if split_team_id[3] in teamArray[-1]:
                        teamArray[-1] = file
                        
                    else:
                        teamArray.append(file)
                else:
                    teamArray.append(file)
            else:
                teamArray.append(file)
        else:
            continue
    return teamArray

# %%
def getValues(str):
    values = str.strip().replace(":", "").split("\n")
    values[0] = values[0][:values[0].index("(")]
    values[2] = values[2][:values[2].index("(")]
    return float(values[0]), float(values[2])

# %%
def removeHeaders(soup):
    for row in soup.find_all("strong"):
        row.decompose()
    return soup

# %%
def get_team_info(team_file, teamInfoDict):
    team_page = read_file(team_file)
    if '2024' in team_file:
        is2024 = True
    else:
        is2024 = False
        
    metaData = team_page.find(id="meta")
    summary = metaData.find(attrs={"data-template": "Partials/Teams/Summary"})
    specificData = summary.find_all("p")

    if is2024:
        indexPPG = 5
        indexSRSPace = 6
        indexOFRtgDFRtg = 7
    else:
        indexPPG = 3
        indexSRSPace = 4
        indexOFRtgDFRtg = 5
        
    team_and_opp_ppg = specificData[indexPPG]
    team_and_opp_ppg = removeHeaders(team_and_opp_ppg)
    teamPPG, oppPPG = getValues(team_and_opp_ppg.text)

    SRS_and_pace = specificData[indexSRSPace]
    SRS_and_pace = removeHeaders(SRS_and_pace)
    SRS, pace = getValues(SRS_and_pace.text)

    team_OFRtg_and_DFRtg = specificData[indexOFRtgDFRtg]
    team_OFRtg_and_DFRtg = removeHeaders(team_OFRtg_and_DFRtg)
    teamOFRtg, teamDFRtg = getValues(team_OFRtg_and_DFRtg.text)

    teamInfoDict['teamPPG'].append(teamPPG)
    teamInfoDict['oppPPG'].append(oppPPG)
    teamInfoDict['SRS'].append(SRS)
    teamInfoDict['pace'].append(pace)
    teamInfoDict['teamOFRtg'].append(teamOFRtg)
    teamInfoDict['teamDFRtg'].append(teamDFRtg)

# %%
def removeMultipleTeams(table):
    curYear = 0
    multipleYear = 0
    for row in table.find_all("tr"):
        curYear = row.find(attrs={"data-stat": "season"})
        if (curYear):
            curYear = curYear.text
            if row.find(attrs={"data-stat": "team_id"}).text == "TOT":
                multipleYear = curYear
                continue
            if curYear == multipleYear:
                row.decompose()
        else:
            row.decompose()
    return table

# %%
def parse_per_game_html(player_stats):
    per_game_table = soup.find(id="per_game")
    per_game_table_clean = decompose_table(per_game_table)
    per_game_table_clean = removeMultipleTeams(per_game_table_clean)

    return per_game_table_clean

# %%
def parse_per_36_html(player_page):
    per_36_table = player_page.find(id="per_minute")
    per_36_table_clean = decompose_table(per_36_table)
    per_36_table_clean = removeMultipleTeams(per_36_table_clean)
    
    return per_36_table_clean

# %%
def parse_per_100_html(player_page):
    per_100_table = player_page.find(id="per_poss")
    per_100_table_clean = decompose_table(per_100_table)
    per_100_table_clean = removeMultipleTeams(per_100_table_clean)

    
    return per_100_table_clean

# %%
def parse_advanced_stats_html(player_stats):
    advanced_table = soup.find(id="advanced")
    advanced_table_clean = decompose_table(advanced_table) 
    advanced_table_clean = removeMultipleTeams(advanced_table_clean)

    return advanced_table_clean

# %%
def make_df_per_game_stats(soup, id):
    per_game_df = make_df(soup)
    
    columnNames = ["Season", "AGE", "TM", "LG", "POS" , "G", "GS", "MP", "FG", 
                   "FGA", "FG%", "3P", "3PA", "3P%", "2P", "2PA", "2P%", "eFG%",
                   "FT", "FTA", "FT%", "ORB", "DRB", "TRB", "AST", "STL", "BLK", 
                   "TOV", "PF", "PTS"]
    per_game_df.fillna(0, inplace=True)
    per_game_df.columns = columnNames
    per_game_df['ID'] = id
    return per_game_df

# %%
def make_df_per_36_stats(soup, id):
    per_36_df = make_df(soup)
    
    columnNames = ["Season", "AGE", "TM", "LG", "POS" , "G", "GS", "MP_total", 
                   "FG_36", "FGA_36", "FG%_36", "3P_36", "3PA_36", "3P%_36", 
                   "2P_36", "2PA_36", "2P%_36", "FT_36", "FTA_36", "FT%_36", 
                   "ORB_36", "DRB_36", "TRB_36", "AST_36", "STL_36", "BLK_36", 
                   "TOV_36", "PF_36", "PTS_36"]
    per_36_df.fillna(0, inplace=True)
    per_36_df.columns = columnNames
    per_36_df['ID'] = id
    return per_36_df

# %%
def make_df_per_100_stats(soup, id):
    per_100_df = make_df(soup)
    
    columnNames = ["Season", "AGE", "TM", "LG", "POS" , "G", "GS", "MP_total", 
                   "FG_100", "FGA_100", "FG%_100", "3P_100", "3PA_100", "3P%_100",
                   "2P_100", "2PA_100", "2P%_100", "FT_100", "FTA_100", "FT%_100",
                   "ORB_100", "DRB_100", "TRB_100", "AST_100", "STL_100", "BLK_100", 
                   "TOV_100", "PF_100", "PTS_100", "holder", "ORtg", "DRtg"]
    per_100_df.fillna(0, inplace=True)
    per_100_df.columns = columnNames
    per_100_df =  per_100_df.drop("holder", axis="columns")

    per_100_df['ID'] = id
    return per_100_df

# %%
def make_df_advanced_stats(soup, id):
    advanced_stats_df = make_df(soup)

    columnNames = ["Season", "AGE", "TM", "LG", "POS" , "G", "MP_total", "PER", "TS%", 
                   "3PAr", "FTr", "ORB%", "DRB%%", "TRB%", "AST%", "STL%%", 
                   "BLK%", "TOV%", "USG%", "holder1", "OWS", "DWS", "WS", 
                   "WS/48", "holder2", "OBPM", "DBPM", "BPM", "VORP"]
    
    advanced_stats_df.fillna(0, inplace=True)
    advanced_stats_df.columns = columnNames
    #get rid of blank columns that basketball-reference adds
    advanced_stats_df =  advanced_stats_df.drop("holder1", axis="columns")
    advanced_stats_df =  advanced_stats_df.drop("holder2", axis="columns")

    advanced_stats_df['ID'] = id
    return advanced_stats_df

# %%
for i in range(15, len(player_stats)):
    file = player_stats[i]
    print(file)
    soup = read_file(file)
    teamInfo = {'teamPPG': [], 'oppPPG': [], 'SRS': [], 'pace': [], 'teamOFRtg': [], 'teamDFRtg': []}
    teamList = determine_teams_and_year(soup)
    
    for team in teamList:
        team_file = f'data/nba_team_stats/{team}'
        get_team_info(team_file, teamInfo)
        
    team_stats_df = pd.DataFrame.from_dict(teamInfo)
    
    per_game = parse_per_game_html(soup)
    per_36 = parse_per_36_html(soup)
    per_100 = parse_per_100_html(soup)
    advanced_stats = parse_advanced_stats_html(soup)

    ID = file.split("/")[-1].strip('.html')
    
    if per_game:
        per_game_DF = make_df_per_game_stats(per_game, ID)
        per_36_DF = make_df_per_36_stats(per_36, ID)
        per_100_DF = make_df_per_100_stats(per_100, ID)
        advanced_stats_DF = make_df_advanced_stats(advanced_stats, ID)
        
        #get all the stats into 1 data frame
        allStats = pd.concat([per_game_DF, per_36_DF, per_100_DF, advanced_stats_DF, team_stats_df], axis=1, join="inner")
    
        #remove any duplicate columns (ie. POS, LG, TM, etc.)
        allStats = allStats.loc[:,~allStats.columns.duplicated()]
        
    all_DFs_array.append(allStats)
# Out:
# data/player_stats_2/netora01.html
# data/player_stats_2/jacksju01.html
# data/player_stats_2/ridnolu01.html
# data/player_stats_2/afflaar01.html
# data/player_stats_2/richajo01.html
# data/player_stats_2/thomais02.html
# data/player_stats_2/childjo01.html
# data/player_stats_2/johnsli01.html
# data/player_stats_2/crowdja01.html
# data/player_stats_2/harklma01.html
# data/player_stats_2/fryech01.html
# data/player_stats_2/smithjo03.html
# data/player_stats_2/garcifr01.html
# data/player_stats_2/pargoje01.html
# data/player_stats_2/miltosh01.html
# data/player_stats_2/johnsst04.html
# data/player_stats_2/petrojo01.html
# data/player_stats_2/stephla01.html
# data/player_stats_2/mbahalu01.html
# data/player_stats_2/mayooj01.html
# data/player_stats_2/casspom01.html
# data/player_stats_2/jokicni01.html
# data/player_stats_2/banksma01.html
# data/player_stats_2/mykhasv01.html
# data/player_stats_2/mcgeeja01.html
# data/player_stats_2/lavinza01.html
# data/player_stats_2/harrish01.html
# data/player_stats_2/ajincal01.html
# data/player_stats_2/brookdi01.html
# data/player_stats_2/blatcan01.html
# data/player_stats_2/monkma01.html
# data/player_stats_2/kaponja01.html
# data/player_stats_2/bradlto01.html
# data/player_stats_2/irvinky01.html
# data/player_stats_2/willima01.html
# data/player_stats_2/smithja02.html
# data/player_stats_2/mbengdj01.html
# data/player_stats_2/caulewi01.html
# data/player_stats_2/luwawti01.html
# data/player_stats_2/dunnkr01.html
# data/player_stats_2/horfoal01.html
# data/player_stats_2/forbebr01.html
# data/player_stats_2/aldrico01.html
# data/player_stats_2/barneha02.html
# data/player_stats_2/emmetan01.html
# data/player_stats_2/smithjr01.html
# data/player_stats_2/vonleno01.html
# data/player_stats_2/millspa01.html
# data/player_stats_2/houseda01.html
# data/player_stats_2/chalmma01.html
# data/player_stats_2/blairde01.html
# data/player_stats_2/daniema01.html
# data/player_stats_2/rondora01.html
# data/player_stats_2/wrighbr03.html
# data/player_stats_2/feliccr01.html
# data/player_stats_2/brownsh01.html
# data/player_stats_2/gallida01.html
# data/player_stats_2/hibbero01.html
# data/player_stats_2/finnedo01.html
# data/player_stats_2/siakapa01.html
# data/player_stats_2/howarjo01.html
# data/player_stats_2/watanyu01.html
# data/player_stats_2/whitedj01.html
# data/player_stats_2/sumneed01.html
# data/player_stats_2/bogdabo01.html
# data/player_stats_2/pattepa01.html
# data/player_stats_2/maxieja01.html
# data/player_stats_2/denglu01.html
# data/player_stats_2/vanvlfr01.html
# data/player_stats_2/collini01.html
# data/player_stats_2/silasxa01.html
# data/player_stats_2/outlatr01.html
# data/player_stats_2/harrijo01.html
# data/player_stats_2/ibakase01.html
# data/player_stats_2/smithcr01.html
# data/player_stats_2/stuckro01.html
# data/player_stats_2/hillge01.html
# data/player_stats_2/joneste01.html
# data/player_stats_2/rosste01.html
# data/player_stats_2/craigto01.html
# data/player_stats_2/burketr01.html
# data/player_stats_2/goberru01.html
# data/player_stats_2/bynumwi01.html
# data/player_stats_2/bledser01.html
# data/player_stats_2/clarkia01.html
# data/player_stats_2/mclembe01.html
# data/player_stats_2/bambamo01.html
# data/player_stats_2/monrogr01.html
# data/player_stats_2/holliro01.html
# data/player_stats_2/valende01.html
# data/player_stats_2/mcguido01.html
# data/player_stats_2/gilesha01.html
# data/player_stats_2/pricero01.html
# data/player_stats_2/speigma01.html
# data/player_stats_2/barbole01.html
# data/player_stats_2/telfase01.html
# data/player_stats_2/hendege02.html
# data/player_stats_2/carusal01.html
# data/player_stats_2/wafervo01.html
# data/player_stats_2/oladivi01.html
# data/player_stats_2/pavloal01.html
# data/player_stats_2/watsocj01.html
# data/player_stats_2/holidaa01.html
# data/player_stats_2/jonesde02.html
# data/player_stats_2/parkeja01.html
# data/player_stats_2/robinje01.html
# data/player_stats_2/knoxke01.html
# data/player_stats_2/davisjo02.html
# data/player_stats_2/jenkijo01.html
# data/player_stats_2/cartewe01.html
# data/player_stats_2/lopezro01.html
# data/player_stats_2/hayesch01.html
# data/player_stats_2/valanjo01.html
# data/player_stats_2/korkmfu01.html
# data/player_stats_2/anderal01.html
# data/player_stats_2/greenje02.html
# data/player_stats_2/conlemi01.html
# data/player_stats_2/holidju01.html
# data/player_stats_2/kornelu01.html
# data/player_stats_2/lopezbr01.html
# data/player_stats_2/boganke01.html
# data/player_stats_2/olynyke01.html
# data/player_stats_2/farieke01.html
# data/player_stats_2/hawessp01.html
# data/player_stats_2/doziepj01.html
# data/player_stats_2/diawbo01.html
# data/player_stats_2/liggide01.html
# data/player_stats_2/lucasjo02.html
# data/player_stats_2/hieldbu01.html
# data/player_stats_2/balkmre01.html
# data/player_stats_2/dinwisp01.html
# data/player_stats_2/arizatr01.html
# data/player_stats_2/wadedw01.html
# data/player_stats_2/embiijo01.html
# data/player_stats_2/leoname01.html
# data/player_stats_2/marjabo01.html
# data/player_stats_2/iguodan01.html
# data/player_stats_2/bullore01.html
# data/player_stats_2/hasleud01.html
# data/player_stats_2/douglto01.html
# data/player_stats_2/jonesda02.html
# data/player_stats_2/butleji01.html
# data/player_stats_2/jonesty01.html
# data/player_stats_2/teaguma01.html
# data/player_stats_2/rosede01.html
# data/player_stats_2/hopsosc01.html
# data/player_stats_2/dayeau01.html
# data/player_stats_2/mozgoti01.html
# data/player_stats_2/sextoco01.html
# data/player_stats_2/satorto01.html
# data/player_stats_2/morrima03.html
# data/player_stats_2/fournev01.html
# data/player_stats_2/clarkjo01.html
# data/player_stats_2/thomala01.html
# data/player_stats_2/willish03.html
# data/player_stats_2/brewero02.html
# data/player_stats_2/niangge01.html
# data/player_stats_2/brogdma01.html
# data/player_stats_2/weemsso01.html
# data/player_stats_2/farmajo01.html
# data/player_stats_2/bazemke01.html
# data/player_stats_2/redicjj01.html
# data/player_stats_2/connapa01.html
# data/player_stats_2/harteis01.html
# data/player_stats_2/cookda02.html
# data/player_stats_2/duprero01.html
# data/player_stats_2/okafoja01.html
# data/player_stats_2/songada01.html
# data/player_stats_2/turnemy01.html
# data/player_stats_2/hillso01.html
# data/player_stats_2/livinsh01.html
# data/player_stats_2/udrihbe01.html
# data/player_stats_2/capelca01.html
# data/player_stats_2/grangda01.html
# data/player_stats_2/gilgesh01.html
# data/player_stats_2/josepco01.html
# data/player_stats_2/mccontj01.html
# data/player_stats_2/machasc01.html
# data/player_stats_2/looneke01.html
# data/player_stats_2/holmeri01.html
# data/player_stats_2/bryanth01.html
# data/player_stats_2/martike02.html
# data/player_stats_2/baglema01.html
# data/player_stats_2/haywago01.html
# data/player_stats_2/carteje01.html
# data/player_stats_2/augusdj01.html
# data/player_stats_2/trentga02.html
# data/player_stats_2/muscami01.html
# data/player_stats_2/adebaba01.html
# data/player_stats_2/willide01.html
# data/player_stats_2/bogutan01.html
# data/player_stats_2/brookma01.html
# data/player_stats_2/divindo01.html
# data/player_stats_2/meeksjo01.html
# data/player_stats_2/powelno01.html
# data/player_stats_2/duhonch01.html
# data/player_stats_2/gomesry01.html
# data/player_stats_2/bridgmi02.html
# data/player_stats_2/allenla01.html
# data/player_stats_2/fraziti01.html
# data/player_stats_2/morrima02.html
# data/player_stats_2/greenge01.html
# data/player_stats_2/willish02.html
# data/player_stats_2/breweco01.html
# data/player_stats_2/gortama01.html
# data/player_stats_2/dekkesa01.html
# data/player_stats_2/townska01.html
# data/player_stats_2/gibsoda01.html
# data/player_stats_2/couside01.html
# data/player_stats_2/bareajo01.html
# data/player_stats_2/hansbty01.html
# data/player_stats_2/sessira01.html
# data/player_stats_2/gallola01.html
# data/player_stats_2/bassbr01.html
# data/player_stats_2/jonesda03.html
# data/player_stats_2/serapke01.html
# data/player_stats_2/crabbal01.html
# data/player_stats_2/warriha01.html
# data/player_stats_2/colliza01.html
# data/player_stats_2/odengr01.html
# data/player_stats_2/azubuke01.html
# data/player_stats_2/lillada01.html
# data/player_stats_2/macksh01.html
# data/player_stats_2/boshch01.html
# data/player_stats_2/aminual01.html
# data/player_stats_2/highsha01.html
# data/player_stats_2/asikom01.html
# data/player_stats_2/grahade01.html
# data/player_stats_2/brunsja01.html
# data/player_stats_2/murrade01.html
# data/player_stats_2/ellismo01.html
# data/player_stats_2/jennibr01.html
# data/player_stats_2/templga01.html
# data/player_stats_2/bartowi01.html
# data/player_stats_2/willike04.html
# data/player_stats_2/adamsst01.html
# data/player_stats_2/ellinwa01.html
# data/player_stats_2/walkebi01.html
# data/player_stats_2/koufoko01.html
# data/player_stats_2/covinro01.html
# data/player_stats_2/splitti01.html
# data/player_stats_2/anderry01.html
# data/player_stats_2/shamela01.html
# data/player_stats_2/sandela01.html
# data/player_stats_2/dragigo01.html
# data/player_stats_2/huertke01.html
# data/player_stats_2/jordade01.html
# data/player_stats_2/allento01.html
# data/player_stats_2/stausni01.html
# data/player_stats_2/mcgruro01.html
# data/player_stats_2/thomaty01.html
# data/player_stats_2/zubaciv01.html
# data/player_stats_2/simmobe01.html
# data/player_stats_2/knighbr03.html
# data/player_stats_2/johnswe01.html
# data/player_stats_2/crawfjo02.html
# data/player_stats_2/mitchdo01.html
# data/player_stats_2/whitede01.html
# data/player_stats_2/holidjr01.html
# data/player_stats_2/pondequ01.html
# data/player_stats_2/kleizli01.html
# data/player_stats_2/delfica01.html
# data/player_stats_2/roziete01.html
# data/player_stats_2/antetgi01.html
# data/player_stats_2/leeda02.html
# data/player_stats_2/hicksjj01.html
# data/player_stats_2/georgpa01.html
# data/player_stats_2/gasolma01.html
# data/player_stats_2/foxde01.html
# data/player_stats_2/brookaa01.html
# data/player_stats_2/derozde01.html
# data/player_stats_2/browntr01.html
# data/player_stats_2/pekovni01.html
# data/player_stats_2/bonnema01.html
# data/player_stats_2/mccolcj01.html
# data/player_stats_2/toupaax01.html
# data/player_stats_2/milleda01.html
# data/player_stats_2/beaslmi01.html
# data/player_stats_2/hardati02.html
# data/player_stats_2/udokaim01.html
# data/player_stats_2/leonaka01.html
# data/player_stats_2/nelsoja01.html
# data/player_stats_2/zelleco01.html
# data/player_stats_2/bradlav01.html
# data/player_stats_2/obertfa01.html
# data/player_stats_2/saricda01.html
# data/player_stats_2/greenwi01.html
# data/player_stats_2/dioguik01.html
# data/player_stats_2/gibsota01.html
# data/player_stats_2/gordobe01.html
# data/player_stats_2/reedda01.html
# data/player_stats_2/whiteja02.html
# data/player_stats_2/waitedi01.html
# data/player_stats_2/duranke01.html
# data/player_stats_2/bateske01.html
# data/player_stats_2/wilkida02.html
# data/player_stats_2/canaais01.html
# data/player_stats_2/willide02.html
# data/player_stats_2/anderky01.html
# data/player_stats_2/perkike01.html
# data/player_stats_2/sefolth01.html
# data/player_stats_2/robinna01.html
# data/player_stats_2/hernaju01.html
# data/player_stats_2/exumda01.html
# data/player_stats_2/walljo01.html
# data/player_stats_2/stoneju01.html
# data/player_stats_2/greendr01.html
# data/player_stats_2/mahinia01.html
# data/player_stats_2/roberan03.html
# data/player_stats_2/osmande01.html
# data/player_stats_2/bridgmi01.html
# data/player_stats_2/simonan01.html
# data/player_stats_2/turiaro01.html
# data/player_stats_2/jackja01.html
# data/player_stats_2/harrima01.html
# data/player_stats_2/bayleje01.html
# data/player_stats_2/fordtj01.html
# data/player_stats_2/westda01.html
# data/player_stats_2/walkeke02.html
# data/player_stats_2/fultzma01.html
# data/player_stats_2/murraja01.html
# data/player_stats_2/isaacjo01.html
# data/player_stats_2/cabocbr01.html
# data/player_stats_2/bynuman01.html
# data/player_stats_2/pachuza01.html
# data/player_stats_2/greenda02.html
# data/player_stats_2/nurkiju01.html
# data/player_stats_2/metuch01.html
# data/player_stats_2/udohek01.html
# data/player_stats_2/bealbr01.html
# data/player_stats_2/anderju01.html
# data/player_stats_2/teaguje01.html
# data/player_stats_2/barroea01.html
# data/player_stats_2/robinmi01.html
# data/player_stats_2/oquinky01.html
# data/player_stats_2/lawsoty01.html
# data/player_stats_2/markkla01.html
# data/player_stats_2/hayesja01.html
# data/player_stats_2/teletmi01.html
# data/player_stats_2/plumlmi01.html
# data/player_stats_2/feltora01.html
# data/player_stats_2/matthwe02.html
# data/player_stats_2/randlju01.html
# data/player_stats_2/howardw01.html
# data/player_stats_2/gordoaa01.html
# data/player_stats_2/anderja01.html
# data/player_stats_2/gordoer01.html
# data/player_stats_2/thompkl01.html
# data/player_stats_2/vucevni01.html
# data/player_stats_2/aldrila01.html
# data/player_stats_2/klebima01.html
# data/player_stats_2/bouchch01.html
# data/player_stats_2/morrimo01.html
# data/player_stats_2/scottmi01.html
# data/player_stats_2/blakest01.html
# data/player_stats_2/snellto01.html
# data/player_stats_2/grayaa01.html
# data/player_stats_2/grahajo01.html
# data/player_stats_2/wiggian01.html
# data/player_stats_2/brownlo01.html
# data/player_stats_2/walkelo01.html
# data/player_stats_2/carroma01.html
# data/player_stats_2/rossqu01.html
# data/player_stats_2/leverca01.html
# data/player_stats_2/nunnaja01.html
# data/player_stats_2/biedran01.html
# data/player_stats_2/wrighdo01.html
# data/player_stats_2/beverpa01.html
# data/player_stats_2/dorsejo01.html
# data/player_stats_2/hardeja01.html
# data/player_stats_2/bjeline01.html
# data/player_stats_2/johnsty01.html
# data/player_stats_2/novakst01.html
# data/player_stats_2/landrca01.html
# data/player_stats_2/davised01.html
# data/player_stats_2/hilljo01.html
# data/player_stats_2/middlkh01.html
# data/player_stats_2/harrito02.html
# data/player_stats_2/paytoel01.html
# data/player_stats_2/wagnemo01.html
# data/player_stats_2/nealga01.html
# data/player_stats_2/hinriki01.html
# data/player_stats_2/okogijo01.html
# data/player_stats_2/bookede01.html
# data/player_stats_2/jacksre01.html
# data/player_stats_2/leeda03.html
# data/player_stats_2/thomptr01.html
# data/player_stats_2/mooreet01.html
# data/player_stats_2/antetth01.html
# data/player_stats_2/birchkh01.html
# data/player_stats_2/rodrise01.html
# data/player_stats_2/griffbl01.html
# data/player_stats_2/brownst02.html
# data/player_stats_2/paytoga02.html
# data/player_stats_2/arcidry01.html
# data/player_stats_2/bembrde01.html
# data/player_stats_2/loveke01.html
# data/player_stats_2/amundlo01.html
# data/player_stats_2/davisgl01.html
# data/player_stats_2/johnsam01.html
# data/player_stats_2/tatumja01.html
# data/player_stats_2/morroan01.html
# data/player_stats_2/collijo01.html
# data/player_stats_2/kiddgmi01.html
# data/player_stats_2/batumni01.html
# data/player_stats_2/kennalu01.html
# data/player_stats_2/ilyaser01.html
# data/player_stats_2/porteot01.html
# data/player_stats_2/lambje01.html
# data/player_stats_2/acyqu01.html
# data/player_stats_2/kamanch01.html
# data/player_stats_2/brownja02.html
# data/player_stats_2/baynear01.html
# data/player_stats_2/poeltja01.html
# data/player_stats_2/willire02.html
# data/player_stats_2/youngth01.html
# data/player_stats_2/smithde03.html
# data/player_stats_2/allenja01.html
# data/player_stats_2/gayru01.html
# data/player_stats_2/motiedo01.html
# data/player_stats_2/inglejo01.html
# data/player_stats_2/babbilu01.html
# data/player_stats_2/kanteen01.html
# data/player_stats_2/korveky01.html
# data/player_stats_2/vasqugr01.html
# data/player_stats_2/randoan01.html
# data/player_stats_2/meltode01.html
# data/player_stats_2/seldewa01.html
# data/player_stats_2/onealro01.html
# data/player_stats_2/krstine01.html
# data/player_stats_2/williro04.html
# data/player_stats_2/bargnan01.html
# data/player_stats_2/shumpim01.html
# data/player_stats_2/portibo01.html
# data/player_stats_2/fredeji01.html
# data/player_stats_2/johnsja01.html
# data/player_stats_2/vandeja01.html
# data/player_stats_2/webstma02.html
# data/player_stats_2/plumlma01.html
# data/player_stats_2/scolalu01.html
# data/player_stats_2/simmoko01.html
# data/player_stats_2/cookbr01.html
# data/player_stats_2/foyera01.html
# data/player_stats_2/jerebjo01.html
# data/player_stats_2/robindu01.html
# data/player_stats_2/allengr01.html
# data/player_stats_2/arthuda01.html
# data/player_stats_2/warretj01.html
# data/player_stats_2/laymaja01.html
# data/player_stats_2/singlky01.html
# data/player_stats_2/wrighan01.html
# data/player_stats_2/zellety01.html
# data/player_stats_2/coleno01.html
# data/player_stats_2/westbru01.html
# data/player_stats_2/anthoca01.html
# data/player_stats_2/geeal01.html
# data/player_stats_2/leeco01.html
# data/player_stats_2/millspa02.html
# data/player_stats_2/brownbo02.html
# data/player_stats_2/varejan01.html
# data/player_stats_2/davisan02.html
# data/player_stats_2/parsoch01.html
# data/player_stats_2/turneev01.html
# data/player_stats_2/thornma01.html
# data/player_stats_2/carrode01.html
# data/player_stats_2/favorde01.html
# data/player_stats_2/jonesja02.html
# data/player_stats_2/budinch01.html
# data/player_stats_2/riverau01.html
# data/player_stats_2/greenja01.html
# data/player_stats_2/dellama01.html
# data/player_stats_2/harremo01.html
# data/player_stats_2/barnema02.html
# data/player_stats_2/napiesh01.html
# data/player_stats_2/mudiaem01.html
# data/player_stats_2/hernawi01.html
# data/player_stats_2/hoodro01.html
# data/player_stats_2/lowryky01.html
# data/player_stats_2/martica01.html
# data/player_stats_2/jeffeal01.html
# data/player_stats_2/chandwi01.html
# data/player_stats_2/conrowi01.html
# data/player_stats_2/woodch01.html
# data/player_stats_2/bogdabo02.html
# data/player_stats_2/mcderdo01.html
# data/player_stats_2/gelabmi01.html
# data/player_stats_2/caldejo01.html
# data/player_stats_2/clarkea01.html
# data/player_stats_2/brownbr01.html
# data/player_stats_2/hensojo01.html
# data/player_stats_2/tollian01.html
# data/player_stats_2/kuzmaky01.html
# data/player_stats_2/harriga01.html
# data/player_stats_2/youngni01.html
# data/player_stats_2/robingl02.html
# data/player_stats_2/dienggo01.html
# data/player_stats_2/noahjo01.html
# data/player_stats_2/paulch01.html
# data/player_stats_2/chrisma01.html
# data/player_stats_2/sampsja02.html
# data/player_stats_2/quinnch01.html
# data/player_stats_2/dudleja01.html
# data/player_stats_2/jamesle01.html
# data/player_stats_2/harride01.html
# data/player_stats_2/grahast01.html
# data/player_stats_2/beaslma01.html
# data/player_stats_2/iveyro01.html
# data/player_stats_2/roybr01.html
# data/player_stats_2/diallch01.html
# data/player_stats_2/okafoem01.html
# data/player_stats_2/ntilila01.html
# data/player_stats_2/smithis01.html
# data/player_stats_2/evansty01.html
# data/player_stats_2/villach01.html
# data/player_stats_2/nwabada01.html
# data/player_stats_2/greenor01.html
# data/player_stats_2/vujacsa01.html
# data/player_stats_2/anunoog01.html
# data/player_stats_2/lylestr01.html
# data/player_stats_2/booketr01.html
# data/player_stats_2/aytonde01.html
# data/player_stats_2/willilo02.html
# data/player_stats_2/wrighde01.html
# data/player_stats_2/singlja01.html
# data/player_stats_2/willima02.html
# data/player_stats_2/nancela02.html
# data/player_stats_2/douglch01.html
# data/player_stats_2/jonesso01.html
# data/player_stats_2/armsthi01.html
# data/player_stats_2/jacksja02.html
# data/player_stats_2/smartma01.html
# data/player_stats_2/pendeje02.html
# data/player_stats_2/westde01.html
# data/player_stats_2/bertada01.html
# data/player_stats_2/stephdj01.html
# data/player_stats_2/curryse01.html
# data/player_stats_2/grantje01.html
# data/player_stats_2/kaminfr01.html
# data/player_stats_2/theisda01.html
# data/player_stats_2/thompja02.html
# data/player_stats_2/waltolu01.html
# data/player_stats_2/nocioan01.html
# data/player_stats_2/harrimi01.html
# data/player_stats_2/harpeju01.html
# data/player_stats_2/anthojo01.html
# data/player_stats_2/mcrobjo01.html
# data/player_stats_2/cartemi01.html
# data/player_stats_2/dorsety01.html
# data/player_stats_2/cunnida01.html
# data/player_stats_2/doncilu01.html
# data/player_stats_2/porzikr01.html
# data/player_stats_2/ingrabr01.html
# data/player_stats_2/elsonfr01.html
# data/player_stats_2/hartjo01.html
# data/player_stats_2/milescj01.html
# data/player_stats_2/evansje01.html
# data/player_stats_2/caldwke01.html
# data/player_stats_2/burksal01.html
# data/player_stats_2/youngtr01.html

# %%
print(len(all_DFs_array))
# Out:
# 17

# %%
file = "data/player_stats_2/whiteha01.html"
print(file)
soup = read_file(file)
teamInfo = {'teamPPG': [], 'oppPPG': [], 'SRS': [], 'pace': [], 'teamOFRtg': [], 'teamDFRtg': []}
teamList = determine_teams_and_year(soup)

for team in teamList:
    team_file = f'data/nba_team_stats/{team}'
    get_team_info(team_file, teamInfo)
    
team_stats_df = pd.DataFrame.from_dict(teamInfo)

per_game = parse_per_game_html(soup)
per_36 = parse_per_36_html(soup)
per_100 = parse_per_100_html(soup)
advanced_stats = parse_advanced_stats_html(soup)

ID = file.split("/")[-1].strip('.html')

if per_game:
    per_game_DF = make_df_per_game_stats(per_game, ID)
    per_36_DF = make_df_per_36_stats(per_36, ID)
    per_100_DF = make_df_per_100_stats(per_100, ID)
    advanced_stats_DF = make_df_advanced_stats(advanced_stats, ID)
    
    #get all the stats into 1 data frame
    allStats = pd.concat([per_game_DF, per_36_DF, per_100_DF, advanced_stats_DF, team_stats_df], axis=1, join="inner")

    #remove any duplicate columns (ie. POS, LG, TM, etc.)
    allStats = allStats.loc[:,~allStats.columns.duplicated()]
all_DFs_array.append(allStats)
allStats
# Out:
# data/player_stats_2/whiteha01.html
# <tbody> <tr class="full_table" data-row="0" id="per_minute.2011"><th class="left" data-stat="season" scope="row"><a href="/players/w/whiteha01/gamelog/2011">2010-11</a></th><td class="center" data-stat="age">21</td><td class="left" data-stat="team_id"><a href="/teams/SAC/2011.html">SAC</a></td><td class="left" data-stat="lg_id"><a href="/leagues/NBA_2011.html">NBA</a></td><td class="center" data-stat="pos">C</td><td class="right" data-stat="g">1</td><td class="right iz" data-stat="gs">0</td><td class="right" data-stat="mp">2</td><td class="right iz" data-stat="fg_per_mp">0.0</td><td class="right iz" data-stat="fga_per_mp">0.0</td><td class="right iz" data-stat="fg_pct"></td><td class="right iz" data-stat="fg3_per_mp">0.0</td><td class="right iz" data-stat="fg3a_per_mp">0.0</td><td class="right iz" data-stat="fg3_pct"></td><td class="right iz" data-stat="fg2_per_mp">0.0</td><td class="right iz" data-stat="fg2a_per_mp">0.0</td><td class="right iz" data-stat="fg2_pct"></td><td class="right iz" data-stat="ft_per_mp">0.0</td><td class="right iz" data-stat="fta_per_mp">0.0</td><td class="right iz" data-stat="ft_pct"></td><td class="right iz" data-stat="orb_per_mp">0.0</td><td class="right iz" data-stat="drb_per_mp">0.0</td><td class="right iz" data-stat="trb_per_mp">0.0</td><td class="right iz" data-stat="ast_per_mp">0.0</td><td class="right iz" data-stat="stl_per_mp">0.0</td><td class="right iz" data-stat="blk_per_mp">0.0</td><td class="right iz" data-stat="tov_per_mp">0.0</td><td class="right" data-stat="pf_per_mp">36.0</td><td class="right iz" data-stat="pts_per_mp">0.0</td></tr> <tr class="full_table" data-row="1" id="per_minute.2012"><th class="left" data-stat="season" scope="row"><a href="/players/w/whiteha01/gamelog/2012">2011-12</a></th><td class="center" data-stat="age">22</td><td class="left" data-stat="team_id"><a href="/teams/SAC/2012.html">SAC</a></td><td class="left" data-stat="lg_id"><a href="/leagues/NBA_2012.html">NBA</a></td><td class="center" data-stat="pos">C</td><td class="right" data-stat="g">18</td><td class="right iz" data-stat="gs">0</td><td class="right" data-stat="mp">109</td><td class="right" data-stat="fg_per_mp">4.0</td><td class="right" data-stat="fga_per_mp">8.9</td><td class="right" data-stat="fg_pct">.444</td><td class="right iz" data-stat="fg3_per_mp">0.0</td><td class="right iz" data-stat="fg3a_per_mp">0.0</td><td class="right iz" data-stat="fg3_pct"></td><td class="right" data-stat="fg2_per_mp">4.0</td><td class="right" data-stat="fg2a_per_mp">8.9</td><td class="right" data-stat="fg2_pct">.444</td><td class="right" data-stat="ft_per_mp">1.7</td><td class="right" data-stat="fta_per_mp">4.0</td><td class="right" data-stat="ft_pct">.417</td><td class="right" data-stat="orb_per_mp">5.3</td><td class="right" data-stat="drb_per_mp">7.6</td><td class="right" data-stat="trb_per_mp">12.9</td><td class="right iz" data-stat="ast_per_mp">0.0</td><td class="right" data-stat="stl_per_mp">1.0</td><td class="right" data-stat="blk_per_mp">5.0</td><td class="right" data-stat="tov_per_mp">1.7</td><td class="right" data-stat="pf_per_mp">4.0</td><td class="right" data-stat="pts_per_mp">9.6</td></tr> <tr class="full_table" data-row="2" id="per_minute.2015"><th class="left" data-stat="season" scope="row"><a href="/players/w/whiteha01/gamelog/2015">2014-15</a></th><td class="center" data-stat="age">25</td><td class="left" data-stat="team_id"><a href="/teams/MIA/2015.html">MIA</a></td><td class="left" data-stat="lg_id"><a href="/leagues/NBA_2015.html">NBA</a></td><td class="center" data-stat="pos">C</td><td class="right" data-stat="g">48</td><td class="right" data-stat="gs">32</td><td class="right" data-stat="mp">1142</td><td class="right" data-stat="fg_per_mp">7.7</td><td class="right" data-stat="fga_per_mp">12.2</td><td class="right" data-stat="fg_pct">.628</td><td class="right iz" data-stat="fg3_per_mp">0.0</td><td class="right iz" data-stat="fg3a_per_mp">0.0</td><td class="right iz" data-stat="fg3_pct"></td><td class ...
# <td class="left" data-stat="team_id"><a href="/teams/SAC/2011.html">SAC</a></td>
# <td class="left" data-stat="team_id"><a href="/teams/SAC/2012.html">SAC</a></td>
# <td class="left" data-stat="team_id"><a href="/teams/MIA/2015.html">MIA</a></td>
# <td class="left" data-stat="team_id"><a href="/teams/MIA/2016.html">MIA</a></td>
# <td class="left" data-stat="team_id"><a href="/teams/MIA/2017.html">MIA</a></td>
# <td class="left" data-stat="team_id"><a href="/teams/MIA/2018.html">MIA</a></td>
# <td class="left" data-stat="team_id"><a href="/teams/MIA/2019.html">MIA</a></td>
# <td class="left" data-stat="team_id"><a href="/teams/POR/2020.html">POR</a></td>
# <td class="left" data-stat="team_id"><a href="/teams/SAC/2021.html">SAC</a></td>
# <td class="left" data-stat="team_id"><a href="/teams/UTA/2022.html">UTA</a></td>
#     Season  AGE   TM   LG POS   G  GS    MP   FG   FGA  ...  OBPM  DBPM   BPM  \
# 0  2010-11   21  SAC  NBA   C   1   0   2.0  0.0   0.0  ... -27.9   0.0 -27.9
# 1  2011-12   22  SAC  NBA   C  18   0   6.1  0.7   1.5  ...  -2.0   0.4  -1.6
# 2  2014-15   25  MIA  NBA   C  48  32  23.8  5.1   8.1  ...   2.5   1.6   4.1
# 3  2015-16   26  MIA  NBA   C  73  43  29.1  5.7   9.3  ...   1.7   2.4   4.1
# 4  2016-17   27  MIA  NBA   C  77  77  32.6  7.0  12.6  ...   0.9   0.5   1.5
# 5  2017-18   28  MIA  NBA   C  54  54  25.3  5.8  10.7  ...   1.5   1.1   2.6
# 6  2018-19   29  MIA  NBA   C  72  53  23.3  5.4   9.4  ...   1.1   1.2   2.3
# 7  2019-20   30  POR  NBA   C  67  61  30.0  6.5  10.5  ...   2.5   0.7   3.2
# 8  2020-21   31  SAC  NBA   C  36   4  15.2  3.5   6.2  ...  -1.8  -0.4  -2.2
# 9  2021-22   32  UTA  NBA   C  65   8  17.9  3.3   5.1  ...   0.6   1.4   2.1
#
#    VORP  teamPPG  oppPPG   SRS   pace  teamOFRtg  teamDFRtg
# 0   0.0     99.4   104.7 -4.80   95.2      103.5       -5.6
# 1   0.0     98.8   104.4 -4.95   94.7      103.8       -6.0
# 2   1.8     94.7    97.3 -2.92   90.9      103.9       -2.8
# 3   3.3    100.0    98.4  1.50   93.6      106.1        1.7
# 4   2.2    103.2   102.1  0.77   95.2      107.8        1.1
# 5   1.6    103.4   102.9  0.15   95.6      106.8        0.5
# 6   1.8    105.7   105.9 -0.45   98.2      107.3       -0.2
# 7   2.6    115.0   116.1 -0.61  100.7      113.7       -1.1
# 8   0.0    113.7   117.4 -3.45  100.0      113.6       -3.7
# 9   1.2    113.6   107.6  5.67   97.1      116.7        6.2
#
# [10 rows x 102 columns]

# %%
all_players_stats_df = pd.concat(all_DFs_array, ignore_index = True)

# %%
# Out:
# 0       pietrmi01
# 1       pietrmi01
# 2       pietrmi01
# 3       pietrmi01
# 4       pietrmi01
#           ...
# 5284    youngtr01
# 5285    youngtr01
# 5286    youngtr01
# 5287    youngtr01
# 5288    youngtr01
# Name: ID, Length: 5289, dtype: object

# %%
all_players_stats_df.to_csv("all_players_stats.csv")
